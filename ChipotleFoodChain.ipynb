# %% [markdown]
# # Taller de Pandas

# %% [markdown]
# 1. Importe las librerías necesarias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Utilice el conjunto de datos "chipotle.csv"

# %%
df = pd.read_csv('C:/Users/chant/Desktop/PORTAFOLIOS/PRIMER SEMESTRE 2023/PORTAFOLIO GESTION - DE GRACIA, CHANTAL/4 -  Actividades/Laboratorios/LAB6 Python/chipotle.csv')

# %% [markdown]
# 3. Asigne el dataset a una variable llamada chipo.

# %%
chipo = df

# %% [markdown]
# 4. Ver las primeras 10 filas

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# 5. ¿Cuántos registros (observaciones) hay en el conjunto de datos?
#
# Diez.

# %% [markdown]
# 6. Cuántas columnas hay en el conjunto de datos?
#
# Cinco.

# %% [markdown]
# 7. Imprima el nombre de todas las columnas.

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# 8. Cuál fue el plato más pedido?

# %%
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False).head(1)['quantity']
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# 9. Cuántas veces fueron ordenados los platos?

# %%
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False)['quantity']
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %% [markdown]
# 10. Cambie el precio de los platos a flotante.

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:-1]))
chipo.item_price.dtype
# Out:
# dtype('float64')
